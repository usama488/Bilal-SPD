# %% [markdown]
# <a href="https://colab.research.google.com/github/usama488/Bilal-SPD/blob/main/%F0%9F%8F%A5_Hospital_Management_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🏥 **Hospital Management System – Efficient Healthcare, Simplified**

# %% [markdown]
# # Welcome to the **Hospital Management System**, a comprehensive platform designed to streamline and digitize hospital operations. From patient registration and appointment scheduling to medical records, billing, and staff management, our system ensures smooth and efficient healthcare services.
#
# # Built to support hospitals of all sizes, this solution improves coordination between departments, reduces administrative workload, and enhances patient care through accurate and real-time information management.
#
# ---
#
# # 💙 **Deliver better care through smarter management and technology.**

# %% [markdown]
# # https://still-shadow-bbf1.usamabinali132.workers.dev/
