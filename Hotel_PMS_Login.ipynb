# %% [markdown]
# <a href="https://colab.research.google.com/github/usama488/Bilal-SPD/blob/main/Hotel_PMS_Login.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🏨 **Hotel PMS Login – Secure Access to Property Management**

# %% [markdown]
# # Welcome to **Hotel PMS Login**, a secure access portal designed for hotel staff and administrators to manage property operations efficiently. This system ensures authorized access to essential features such as reservations, guest management, billing, and housekeeping.
#
# # With a user-friendly and secure login interface, staff can seamlessly access real-time data, streamline daily operations, and deliver exceptional guest experiences.
#
# ---
#
# # 🔐 **Simplifying hotel operations with secure and reliable access.**

# %% [markdown]
# # https://fancy-cherry-9430.usamabinali132.workers.dev/
