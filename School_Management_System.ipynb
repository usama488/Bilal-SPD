# %% [markdown]
# <a href="https://colab.research.google.com/github/usama488/Bilal-SPD/blob/main/School_Management_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🎓 **School Management System – Smart Education, Simplified**

# %% [markdown]
# # Welcome to the **School Management System**, a comprehensive platform designed to streamline and digitize school operations. From student enrollment and attendance tracking to academic records, fee management, and communication, our system ensures efficient and organized administration.
#
# # Built for modern educational institutions, this solution enhances collaboration between teachers, students, and parents while reducing administrative workload and improving overall productivity.
#
# ---
#
# # 📘 **Empowering education through efficient management and technology.**

# %% [markdown]
# # https://plain-cell-da48.usamabinali132.workers.dev/
